# %%
# Importing dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities_df = pd.DataFrame(cities)
cities_df = cities_df.rename(columns={0: 'City'})
cities_df.head()
# Out:
#            City
# 0    oranjestad
# 1        linxia
# 2  koshurnikovo
# 3        albany
# 4       ushuaia

# %%
# Perform a weather check on each city using a series of successive API calls
url = "http://api.openweathermap.org/data/2.5/weather?"
city_names = []
cloudines = []
countries = []
dates = []
humidities = []
lat = []
lng = []
max_temp = []
wind_speed = []

# index counter
index = 0

for city in cities:
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    time.sleep(1)
    response = requests.get(query_url)
    weather_response = response.json()
        
    # Include a print log of each city as it's being processed (with the city number and city name).
    
    print("Processing record # " + str(index) + ": " + city)
    index += 1

    try:
        city = weather_response['name']
        cloudiness = weather_response['clouds']['all']
        country = weather_response['sys']['country']
        date = weather_response['dt']
        humidity = weather_response['main']['humidity']
        lats = weather_response['coord']['lat']
        lngs = weather_response['coord']['lon']
        mx_temp = weather_response['main']['temp_max']
        wind_sp = weather_response['wind']['speed']

        city_names.append(city)
        cloudines.append(cloudiness)
        countries.append(country)
        dates.append(date)
        humidities.append(humidity)
        lat.append(lats)
        lng.append(lngs)
        max_temp.append(mx_temp)
        wind_speed.append(wind_sp)
        print("Retrieving Data.")

    except:
        print("City data not found. Skipping city")
        continue

summary = {'City': city_names,
          'Cloudiness (%)': cloudines,
          'Country': countries,
          'Date': dates,
          'Humidity': humidities,
          'Latitude': lat,
          'Longitude': lng,
          'Max Temp': max_temp,
          'Wind Speed': wind_speed}
city_temp_df = pd.DataFrame(summary)
city_temp_df.head()
# Out:
# Processing record # 0: oranjestad
# Retrieving Data.
# Processing record # 1: linxia
# Retrieving Data.
# Processing record # 2: koshurnikovo
# Retrieving Data.
# Processing record # 3: albany
# Retrieving Data.
# Processing record # 4: ushuaia
# Retrieving Data.
# Processing record # 5: umzimvubu
# City data not found. Skipping city
# Processing record # 6: dikson
# Retrieving Data.
# Processing record # 7: rungata
# City data not found. Skipping city
# Processing record # 8: yellowknife
# Retrieving Data.
# Processing record # 9: sitka
# Retrieving Data.
# Processing record # 10: auki
# Retrieving Data.
# Processing record # 11: temba
# Retrieving Data.
# Processing record # 12: tastur
# Retrieving Data.
# Processing record # 13: leningradskiy
# Retrieving Data.
# Processing record # 14: cidreira
# Retrieving Data.
# Processing record # 15: boshnyakovo
# Retrieving Data.
# Processing record # 16: bethel
# Retrieving Data.
# Processing record # 17: castro
# Retrieving Data.
# Processing record # 18: puerto leguizamo
# Retrieving Data.
# Processing record # 19: sri aman
# Retrieving Data.
# Processing record # 20: merauke
# Retrieving Data.
# Processing record # 21: jamestown
# Retrieving Data.
# Processing record # 22: clyde river
# Retrieving Data.
# Processing record # 23: tocopilla
# Retrieving Data.
# Processing record # 24: thompson
# Retrieving Data.
# Processing record # 25: klaksvik
# Retrieving Data.
# Processing record # 26: hermanus
# Retrieving Data.
# Processing record # 27: port alfred
# Retrieving Data.
# Processing record # 28: rikitea
# Retrieving Data.
# Processing record # 29: hilo
# Retrieving Data.
# Processing record # 30: lorengau
# Retrieving Data.
# Processing record # 31: saint charles
# Retrieving Data.
# Processing record # 32: asfi
# Retrieving Data.
# Processing record # 33: vredendal
# Retrieving Data.
# Processing record # 34: punta arenas
# Retrieving Data.
# Processing record # 35: prince albert
# Retrieving Data.
# Processing record # 36: atuona
# Retrieving Data.
# Processing record # 37: atikokan
# Retrieving Data.
# Processing record # 38: attawapiskat
# City data not found. Skipping city
# Processing record # 39: kudahuvadhoo
# Retrieving Data.
# Processing record # 40: vaini
# Retrieving Data.
# Processing record # 41: arraial do cabo
# Retrieving Data.
# Processing record # 42: butaritari
# Retrieving Data.
# Processing record # 43: salalah
# Retrieving Data.
# Processing record # 44: santana do livramento
# Retrieving Data.
# Processing record # 45: mataura
# Retrieving Data.
# Processing record # 46: ulaanbaatar
# Retrieving Data.
# Processing record # 47: kabare
# Retrieving Data.
# Processing record # 48: sentyabrskiy
# City data not found. Skipping city
# Processing record # 49: kaupanger
# Retrieving Data.
# Processing record # 50: hithadhoo
# Retrieving Data.
# Processing record # 51: naze
# Retrieving Data.
# Processing record # 52: cayenne
# Retrieving Data.
# Processing record # 53: palabuhanratu
# City data not found. Skipping city
# Processing record # 54: dakar
# Retrieving Data.
# Processing record # 55: saldanha
# Retrieving Data.
# Processing record # 56: cape town
# Retrieving Data.
# Processing record # 57: laguna
# Retrieving Data.
# Processing record # 58: norsup
# Retrieving Data.
# Processing record # 59: marsh harbour
# Retrieving Data.
# Processing record # 60: georgetown
# Retrieving Data.
# Processing record # 61: tasiilaq
# Retrieving Data.
# Processing record # 62: souillac
# Retrieving Data.
# Processing record # 63: lebu
# Retrieving Data.
# Processing record # 64: chokurdakh
# Retrieving Data.
# Processing record # 65: kapaa
# Retrieving Data.
# Processing record # 66: monrovia
# Retrieving Data.
# Processing record # 67: saskylakh
# Retrieving Data.
# Processing record # 68: iquitos
# Retrieving Data.
# Processing record # 69: khao yoi
# Retrieving Data.
# Processing record # 70: tulun
# Retrieving Data.
# Processing record # 71: valente
# Retrieving Data.
# Processing record # 72: tumannyy
# City data not found. Skipping city
# Processing record # 73: amderma
# City data not found. Skipping city
# Processing record # 74: zyryanka
# Retrieving Data.
# Processing record # 75: kuanshan
# City data not found. Skipping city
# Processing record # 76: aksum
# Retrieving Data.
# Processing record # 77: new richmond
# Retrieving Data.
# Processing record # 78: taltal
# Retrieving Data.
# Processing record # 79: slave lake
# Retrieving Data.
# Processing record # 80: todos santos
# Retrieving Data.
# Processing record # 81: tortoli
# Retrieving Data.
# Processing record # 82: duz
# City data not found. Skipping city
# Processing record # 83: tautira
# Retrieving Data.
# Processing record # 84: broken hill
# Retrieving Data.
# Processing record # 85: katherine
# Retrieving Data.
# Processing record # 86: a
# City data not found. Skipping city
# Processing record # 87: marcona
# City data not found. Skipping city
# Processing record # 88: barentsburg
# City data not found. Skipping city
# Processing record # 89: tabou
# Retrieving Data.
# Processing record # 90: englehart
# Retrieving Data.
# Processing record # 91: skalistyy
# City data not found. Skipping city
# Processing record # 92: port hedland
# Retrieving Data.
# Processing record # 93: nikolskoye
# Retrieving Data.
# Processing record # 94: saint george
# Retrieving Data.
# Processing record # 95: bredasdorp
# Retrieving Data.
# Processing record # 96: huarmey
# Retrieving Data.
# Processing record # 97: east london
# Retrieving Data.
# Processing record # 98: krasnoselkup
# Retrieving Data.
# Processing record # 99: new norfolk
# Retrieving Data.
# Processing record # 100: barrow
# Retrieving Data.
# Processing record # 101: blythe
# Retrieving Data.
# Processing record # 102: port elizabeth
# Retrieving Data.
# Processing record # 103: sakakah
# Retrieving Data.
# Processing record # 104: soyo
# Retrieving Data.
# Processing record # 105: itarema
# Retrieving Data.
# Processing record # 106: marang
# Retrieving Data.
# Processing record # 107: taolanaro
# City data not found. Skipping city
# Processing record # 108: hayrabolu
# Retrieving Data.
# Processing record # 109: general roca
# Retrieving Data.
# Processing record # 110: upernavik
# Retrieving Data.
# Processing record # 111: ilulissat
# Retrieving Data.
# Processing record # 112: saint-philippe
# Retrieving Data.
# Processing record # 113: belushya guba
# City data not found. Skipping city
# Processing record # 114: qaanaaq
# Retrieving Data.
# Processing record # 115: newport
# Retrieving Data.
# Processing record # 116: corinto
# Retrieving Data.
# Processing record # 117: hobart
# Retrieving Data.
# Processing record # 118: nome
# Retrieving Data.
# Processing record # 119: havre
# Retrieving Data.
# Processing record # 120: caravelas
# Retrieving Data.
# Processing record # 121: maswa
# Retrieving Data.
# Processing record # 122: bitkine
# Retrieving Data.
# Processing record # 123: bluff
# Retrieving Data.
# Processing record # 124: ostrovnoy
# Retrieving Data.
# Processing record # 125: lolua
# City data not found. Skipping city
# Processing record # 126: busselton
# Retrieving Data.
# Processing record # 127: buariki
# City data not found. Skipping city
# Processing record # 128: mahebourg
# Retrieving Data.
# Processing record # 129: puerto ayora
# Retrieving Data.
# Processing record # 130: soc trang
# Retrieving Data.
# Processing record # 131: ambon
# Retrieving Data.
# Processing record # 132: batemans bay
# Retrieving Data.
# Processing record # 133: molina
# Retrieving Data.
# Processing record # 134: ancud
# Retrieving Data.
# Processing record # 135: xuzhou
# Retrieving Data.
# Processing record # 136: jerez
# Retrieving Data.
# Processing record # 137: opuwo
# Retrieving Data.
# Processing record # 138: bengkulu
# Retrieving Data.
# Processing record # 139: lompoc
# Retrieving Data.
# Processing record # 140: coquimbo
# Retrieving Data.
# Processing record # 141: emerald
# Retrieving Data.
# Processing record # 142: vardo
# Retrieving Data.
# Processing record # 143: anadyr
# Retrieving Data.
# Processing record # 144: avarua
# Retrieving Data.
# Processing record # 145: ponta do sol
# Retrieving Data.
# Processing record # 146: yurga
# Retrieving Data.
# Processing record # 147: tuktoyaktuk
# Retrieving Data.
# Processing record # 148: hambantota
# Retrieving Data.
# Processing record # 149: iqaluit
# Retrieving Data.
# Processing record # 150: kavaratti
# Retrieving Data.
# Processing record # 151: sibu
# Retrieving Data.
# Processing record # 152: lovec
# City data not found. Skipping city
# Processing record # 153: ixtapa
# Retrieving Data.
# Processing record # 154: tabanan
# Retrieving Data.
# Processing record # 155: ban tak
# Retrieving Data.
# Processing record # 156: buala
# Retrieving Data.
# Processing record # 157: nizhneyansk
# City data not found. Skipping city
# Processing record # 158: sao joao da barra
# Retrieving Data.
# Processing record # 159: tobolsk
# Retrieving Data.
# Processing record # 160: ribeira grande
# Retrieving Data.
# Processing record # 161: houma
# Retrieving Data.
# Processing record # 162: kodiak
# Retrieving Data.
# Processing record # 163: ascension
# Retrieving Data.
# Processing record # 164: abalak
# Retrieving Data.
# Processing record # 165: namibe
# Retrieving Data.
# Processing record # 166: aykhal
# Retrieving Data.
# Processing record # 167: kruisfontein
# Retrieving Data.
# Processing record # 168: berlevag
# Retrieving Data.
# Processing record # 169: girua
# Retrieving Data.
# Processing record # 170: bandarbeyla
# Retrieving Data.
# Processing record # 171: buzovna
# Retrieving Data.
# Processing record # 172: longyearbyen
# Retrieving Data.
# Processing record # 173: yabelo
# Retrieving Data.
# Processing record # 174: alofi
# Retrieving Data.
# Processing record # 175: praxedis guerrero
# Retrieving Data.
# Processing record # 176: cabo san lucas
# Retrieving Data.
# Processing record # 177: kikwit
# Retrieving Data.
# Processing record # 178: husavik
# Retrieving Data.
# Processing record # 179: brae
# Retrieving Data.
# Processing record # 180: christchurch
# Retrieving Data.
# Processing record # 181: cranbrook
# Retrieving Data.
# Processing record # 182: ishigaki
# Retrieving Data.
# Processing record # 183: luderitz
# Retrieving Data.
# Processing record # 184: baboua
# City data not found. Skipping city
# Processing record # 185: chiredzi
# Retrieving Data.
# Processing record # 186: anamur
# Retrieving Data.
# Processing record # 187: bathurst
# Retrieving Data.
# Processing record # 188: aljezur
# Retrieving Data.
# Processing record # 189: kokopo
# Retrieving Data.
# Processing record # 190: mullaitivu
# City data not found. Skipping city
# Processing record # 191: torbay
# Retrieving Data.
# Processing record # 192: nadym
# Retrieving Data.
# Processing record # 193: bulaevo
# Retrieving Data.
# Processing record # 194: half moon bay
# Retrieving Data.
# Processing record # 195: aklavik
# Retrieving Data.
# Processing record # 196: tabialan
# City data not found. Skipping city
# Processing record # 197: semirom
# Retrieving Data.
# Processing record # 198: gat
# Retrieving Data.
# Processing record # 199: mys shmidta
# City data not found. Skipping city
# Processing record # 200: pangnirtung
# Retrieving Data.
# Processing record # 201: meulaboh
# Retrieving Data.
# Processing record # 202: atar
# Retrieving Data.
# Processing record # 203: nanortalik
# Retrieving Data.
# Processing record # 204: roebourne
# Retrieving Data.
# Processing record # 205: beboto
# Retrieving Data.
# Processing record # 206: xichang
# Retrieving Data.
# Processing record # 207: gizo
# Retrieving Data.
# Processing record # 208: bambous virieux
# Retrieving Data.
# Processing record # 209: hualmay
# Retrieving Data.
# Processing record # 210: beringovskiy
# Retrieving Data.
# Processing record # 211: port blair
# Retrieving Data.
# Processing record # 212: geldermalsen
# Retrieving Data.
# Processing record # 213: khonuu
# City data not found. Skipping city
# Processing record # 214: terrasini
# Retrieving Data.
# Processing record # 215: fairbanks
# Retrieving Data.
# Processing record # 216: illoqqortoormiut
# City data not found. Skipping city
# Processing record # 217: miyako
# Retrieving Data.
# Processing record # 218: guantanamo
# Retrieving Data.
# Processing record # 219: amapa
# Retrieving Data.
# Processing record # 220: narsaq
# Retrieving Data.
# Processing record # 221: ternate
# Retrieving Data.
# Processing record # 222: dakoro
# Retrieving Data.
# Processing record # 223: borovoy
# Retrieving Data.
# Processing record # 224: port hardy
# Retrieving Data.
# Processing record # 225: tiksi
# Retrieving Data.
# Processing record # 226: shetpe
# Retrieving Data.
# Processing record # 227: aasiaat
# Retrieving Data.
# Processing record # 228: ahipara
# Retrieving Data.
# Processing record # 229: sinnamary
# Retrieving Data.
# Processing record # 230: santa rosa
# Retrieving Data.
# Processing record # 231: bogalusa
# Retrieving Data.
# Processing record # 232: cap malheureux
# Retrieving Data.
# Processing record # 233: erenhot
# Retrieving Data.
# Processing record # 234: boyolangu
# Retrieving Data.
# Processing record # 235: guerrero negro
# Retrieving Data.
# Processing record # 236: palencia
# Retrieving Data.
# Processing record # 237: madiun
# Retrieving Data.
# Processing record # 238: surt
# Retrieving Data.
# Processing record # 239: vostok
# Retrieving Data.
# Processing record # 240: becerril
# Retrieving Data.
# Processing record # 241: grand gaube
# Retrieving Data.
# Processing record # 242: sorland
# Retrieving Data.
# Processing record # 243: grand river south east
# City data not found. Skipping city
# Processing record # 244: rocha
# Retrieving Data.
# Processing record # 245: poso
# Retrieving Data.
# Processing record # 246: manzhouli
# Retrieving Data.
# Processing record # 247: vestmannaeyjar
# Retrieving Data.
# Processing record # 248: okhotsk
# Retrieving Data.
# Processing record # 249: alice springs
# Retrieving Data.
# Processing record # 250: boende
# Retrieving Data.
# Processing record # 251: rioja
# Retrieving Data.
# Processing record # 252: samfya
# Retrieving Data.
# Processing record # 253: hastings
# Retrieving Data.
# Processing record # 254: bairiki
# Retrieving Data.
# Processing record # 255: tigre
# Retrieving Data.
# Processing record # 256: tura
# Retrieving Data.
# Processing record # 257: camacha
# Retrieving Data.
# Processing record # 258: provideniya
# Retrieving Data.
# Processing record # 259: hay river
# Retrieving Data.
# Processing record # 260: ust-nera
# Retrieving Data.
# Processing record # 261: kenai
# Retrieving Data.
# Processing record # 262: labuhan
# Retrieving Data.
# Processing record # 263: illela
# Retrieving Data.
# Processing record # 264: aloleng
# Retrieving Data.
# Processing record # 265: tazovskiy
# Retrieving Data.
# Processing record # 266: andros
# Retrieving Data.
# Processing record # 267: lakhimpur
# Retrieving Data.
# Processing record # 268: hasaki
# Retrieving Data.
# Processing record # 269: polyarnyye zori
# Retrieving Data.
# Processing record # 270: wamba
# Retrieving Data.
# Processing record # 271: donegal
# Retrieving Data.
# Processing record # 272: jiddah
# City data not found. Skipping city
# Processing record # 273: oudtshoorn
# Retrieving Data.
# Processing record # 274: karratha
# Retrieving Data.
# Processing record # 275: minusinsk
# Retrieving Data.
# Processing record # 276: develi
# Retrieving Data.
# Processing record # 277: aden
# Retrieving Data.
# Processing record # 278: broome
# Retrieving Data.
# Processing record # 279: portsmouth
# Retrieving Data.
# Processing record # 280: olafsvik
# Retrieving Data.
# Processing record # 281: kuvshinovo
# Retrieving Data.
# Processing record # 282: harlingen
# Retrieving Data.
# Processing record # 283: vengerovo
# Retrieving Data.
# Processing record # 284: zeya
# Retrieving Data.
# Processing record # 285: bouca
# Retrieving Data.
# Processing record # 286: carbonia
# Retrieving Data.
# Processing record # 287: yenagoa
# Retrieving Data.
# Processing record # 288: sobolevo
# Retrieving Data.
# Processing record # 289: dingle
# Retrieving Data.
# Processing record # 290: aldan
# Retrieving Data.
# Processing record # 291: gamba
# Retrieving Data.
# Processing record # 292: dondo
# Retrieving Data.
# Processing record # 293: arlit
# Retrieving Data.
# Processing record # 294: hami
# Retrieving Data.
# Processing record # 295: port-gentil
# Retrieving Data.
# Processing record # 296: magadan
# Retrieving Data.
# Processing record # 297: inirida
# Retrieving Data.
# Processing record # 298: araouane
# Retrieving Data.
# Processing record # 299: khatanga
# Retrieving Data.
# Processing record # 300: baishishan
# Retrieving Data.
# Processing record # 301: richards bay
# Retrieving Data.
# Processing record # 302: henties bay
# Retrieving Data.
# Processing record # 303: chuy
# Retrieving Data.
# Processing record # 304: dinsor
# City data not found. Skipping city
# Processing record # 305: erzin
# Retrieving Data.
# Processing record # 306: kang
# Retrieving Data.
# Processing record # 307: kavieng
# Retrieving Data.
# Processing record # 308: utraula
# Retrieving Data.
# Processing record # 309: kaitangata
# Retrieving Data.
# Processing record # 310: hwange
# Retrieving Data.
# Processing record # 311: the pas
# Retrieving Data.
# Processing record # 312: viligili
# City data not found. Skipping city
# Processing record # 313: conde
# Retrieving Data.
# Processing record # 314: makakilo city
# Retrieving Data.
# Processing record # 315: killarney
# Retrieving Data.
# Processing record # 316: deputatskiy
# Retrieving Data.
# Processing record # 317: saint-georges
# Retrieving Data.
# Processing record # 318: kuche
# City data not found. Skipping city
# Processing record # 319: the valley
# Retrieving Data.
# Processing record # 320: fort nelson
# Retrieving Data.
# Processing record # 321: saint-joseph
# Retrieving Data.
# Processing record # 322: bilibino
# Retrieving Data.
# Processing record # 323: vanimo
# Retrieving Data.
# Processing record # 324: wagga wagga
# Retrieving Data.
# Processing record # 325: esperance
# Retrieving Data.
# Processing record # 326: seoul
# Retrieving Data.
# Processing record # 327: gravdal
# Retrieving Data.
# Processing record # 328: taburi
# City data not found. Skipping city
# Processing record # 329: kawana waters
# City data not found. Skipping city
# Processing record # 330: wahran
# City data not found. Skipping city
# Processing record # 331: san jose
# Retrieving Data.
# Processing record # 332: victoria
# Retrieving Data.
# Processing record # 333: kuching
# Retrieving Data.
# Processing record # 334: taoudenni
# Retrieving Data.
# Processing record # 335: gao
# Retrieving Data.
# Processing record # 336: miri
# Retrieving Data.
# Processing record # 337: jamame
# Retrieving Data.
# Processing record # 338: louisbourg
# City data not found. Skipping city
# Processing record # 339: pisco
# Retrieving Data.
# Processing record # 340: te anau
# Retrieving Data.
# Processing record # 341: millinocket
# Retrieving Data.
# Processing record # 342: satitoa
# City data not found. Skipping city
# Processing record # 343: chicama
# Retrieving Data.
# Processing record # 344: muravlenko
# Retrieving Data.
# Processing record # 345: haines junction
# Retrieving Data.
# Processing record # 346: dalbandin
# Retrieving Data.
# Processing record # 347: mar del plata
# Retrieving Data.
# Processing record # 348: norman wells
# Retrieving Data.
# Processing record # 349: la ronge
# Retrieving Data.
# Processing record # 350: burgeo
# Retrieving Data.
# Processing record # 351: sao filipe
# Retrieving Data.
# Processing record # 352: wagar
# Retrieving Data.
# Processing record # 353: saleaula
# City data not found. Skipping city
# Processing record # 354: orocue
# Retrieving Data.
# Processing record # 355: hofn
# Retrieving Data.
# Processing record # 356: gerash
# Retrieving Data.
# Processing record # 357: ayan
# Retrieving Data.
# Processing record # 358: san juan
# Retrieving Data.
# Processing record # 359: juneau
# Retrieving Data.
# Processing record # 360: flinders
# Retrieving Data.
# Processing record # 361: dharmavaram
# Retrieving Data.
# Processing record # 362: nara
# Retrieving Data.
# Processing record # 363: mezhova
# Retrieving Data.
# Processing record # 364: moron
# Retrieving Data.
# Processing record # 365: skjervoy
# Retrieving Data.
# Processing record # 366: pevek
# Retrieving Data.
# Processing record # 367: birao
# Retrieving Data.
# Processing record # 368: javanrud
# Retrieving Data.
# Processing record # 369: lasa
# Retrieving Data.
# Processing record # 370: rey bouba
# Retrieving Data.
# Processing record # 371: sayat
# Retrieving Data.
# Processing record # 372: havoysund
# Retrieving Data.
# Processing record # 373: bethlehem
# Retrieving Data.
# Processing record # 374: santiago de cao
# Retrieving Data.
# Processing record # 375: howard springs
# Retrieving Data.
# Processing record # 376: olhao
# Retrieving Data.
# Processing record # 377: saint-augustin
# Retrieving Data.
# Processing record # 378: vila velha
# Retrieving Data.
# Processing record # 379: lagoa
# Retrieving Data.
# Processing record # 380: acapulco
# Retrieving Data.
# Processing record # 381: rozsypne
# Retrieving Data.
# Processing record # 382: nioro
# Retrieving Data.
# Processing record # 383: kroya
# Retrieving Data.
# Processing record # 384: terrak
# Retrieving Data.
# Processing record # 385: kwekwe
# Retrieving Data.
# Processing record # 386: vaitupu
# City data not found. Skipping city
# Processing record # 387: srivardhan
# Retrieving Data.
# Processing record # 388: turukhansk
# Retrieving Data.
# Processing record # 389: camocim
# Retrieving Data.
# Processing record # 390: burnie
# Retrieving Data.
# Processing record # 391: thurso
# Retrieving Data.
# Processing record # 392: grindavik
# Retrieving Data.
# Processing record # 393: riyadh
# Retrieving Data.
# Processing record # 394: srednekolymsk
# Retrieving Data.
# Processing record # 395: bendigo
# Retrieving Data.
# Processing record # 396: sakaiminato
# Retrieving Data.
# Processing record # 397: sao joaquim
# Retrieving Data.
# Processing record # 398: asau
# Retrieving Data.
# Processing record # 399: dickinson
# Retrieving Data.
# Processing record # 400: floro
# Retrieving Data.
# Processing record # 401: aguimes
# Retrieving Data.
# Processing record # 402: makat
# Retrieving Data.
# Processing record # 403: mecca
# Retrieving Data.
# Processing record # 404: geraldton
# Retrieving Data.
# Processing record # 405: kadoma
# Retrieving Data.
# Processing record # 406: tuatapere
# Retrieving Data.
# Processing record # 407: talcahuano
# Retrieving Data.
# Processing record # 408: west wendover
# Retrieving Data.
# Processing record # 409: likasi
# Retrieving Data.
# Processing record # 410: syracuse
# Retrieving Data.
# Processing record # 411: sofiysk
# City data not found. Skipping city
# Processing record # 412: ahuimanu
# Retrieving Data.
# Processing record # 413: olga
# Retrieving Data.
# Processing record # 414: codrington
# Retrieving Data.
# Processing record # 415: mae sai
# Retrieving Data.
# Processing record # 416: long xuyen
# Retrieving Data.
# Processing record # 417: lavrentiya
# Retrieving Data.
# Processing record # 418: kirovskiy
# Retrieving Data.
# Processing record # 419: miraflores
# Retrieving Data.
# Processing record # 420: aksarayskiy
# Retrieving Data.
# Processing record # 421: kiunga
# Retrieving Data.
# Processing record # 422: minab
# Retrieving Data.
# Processing record # 423: karakol
# Retrieving Data.
# Processing record # 424: cheremisinovo
# Retrieving Data.
# Processing record # 425: shizunai
# Retrieving Data.
# Processing record # 426: maarianhamina
# Retrieving Data.
# Processing record # 427: wanning
# Retrieving Data.
# Processing record # 428: pirapora
# Retrieving Data.
# Processing record # 429: constitucion
# Retrieving Data.
# Processing record # 430: kulu
# Retrieving Data.
# Processing record # 431: yulara
# Retrieving Data.
# Processing record # 432: lahaina
# Retrieving Data.
# Processing record # 433: samusu
# City data not found. Skipping city
# Processing record # 434: quang ngai
# Retrieving Data.
# Processing record # 435: mackenzie
# Retrieving Data.
# Processing record # 436: longlac
# City data not found. Skipping city
# Processing record # 437: hamilton
# Retrieving Data.
# Processing record # 438: san quintin
# Retrieving Data.
# Processing record # 439: port augusta
# Retrieving Data.
# Processing record # 440: hanzhong
# Retrieving Data.
# Processing record # 441: rio grande
# Retrieving Data.
# Processing record # 442: jesus carranza
# Retrieving Data.
# Processing record # 443: reni
# Retrieving Data.
# Processing record # 444: plaster rock
# Retrieving Data.
# Processing record # 445: lunavada
# Retrieving Data.
# Processing record # 446: whitehorse
# Retrieving Data.
# Processing record # 447: khandyga
# Retrieving Data.
# Processing record # 448: jega
# Retrieving Data.
# Processing record # 449: warrington
# Retrieving Data.
# Processing record # 450: cabedelo
# Retrieving Data.
# Processing record # 451: san cristobal
# Retrieving Data.
# Processing record # 452: sioux lookout
# Retrieving Data.
# Processing record # 453: ilhabela
# Retrieving Data.
# Processing record # 454: harper
# Retrieving Data.
# Processing record # 455: kholmogory
# Retrieving Data.
# Processing record # 456: tiarei
# Retrieving Data.
# Processing record # 457: pousat
# City data not found. Skipping city
# Processing record # 458: santa cruz de la palma
# Retrieving Data.
# Processing record # 459: cherskiy
# Retrieving Data.
# Processing record # 460: javornik
# Retrieving Data.
# Processing record # 461: ossora
# Retrieving Data.
# Processing record # 462: san patricio
# Retrieving Data.
# Processing record # 463: parichha
# Retrieving Data.
# Processing record # 464: airai
# Retrieving Data.
# Processing record # 465: benghazi
# Retrieving Data.
# Processing record # 466: nuuk
# Retrieving Data.
# Processing record # 467: ayer itam
# City data not found. Skipping city
# Processing record # 468: meiganga
# Retrieving Data.
# Processing record # 469: sittingbourne
# Retrieving Data.
# Processing record # 470: oussouye
# Retrieving Data.
# Processing record # 471: lethem
# Retrieving Data.
# Processing record # 472: yumen
# Retrieving Data.
# Processing record # 473: touros
# Retrieving Data.
# Processing record # 474: carnarvon
# Retrieving Data.
# Processing record # 475: colares
# Retrieving Data.
# Processing record # 476: nkhotakota
# Retrieving Data.
# Processing record # 477: tarudant
# City data not found. Skipping city
# Processing record # 478: saiha
# Retrieving Data.
# Processing record # 479: nacogdoches
# Retrieving Data.
# Processing record # 480: teahupoo
# Retrieving Data.
# Processing record # 481: waddan
# Retrieving Data.
# Processing record # 482: aksay
# Retrieving Data.
# Processing record # 483: necochea
# Retrieving Data.
# Processing record # 484: ayagoz
# Retrieving Data.
# Processing record # 485: babocsa
# Retrieving Data.
# Processing record # 486: strathmore
# Retrieving Data.
# Processing record # 487: loralai
# Retrieving Data.
# Processing record # 488: samarai
# Retrieving Data.
# Processing record # 489: cienaga de flores
# City data not found. Skipping city
# Processing record # 490: paamiut
# Retrieving Data.
# Processing record # 491: murray bridge
# Retrieving Data.
# Processing record # 492: san borja
# Retrieving Data.
# Processing record # 493: biograd na moru
# Retrieving Data.
# Processing record # 494: vila franca do campo
# Retrieving Data.
# Processing record # 495: adrar
# Retrieving Data.
# Processing record # 496: palmer
# Retrieving Data.
# Processing record # 497: dori
# Retrieving Data.
# Processing record # 498: cucutilla
# Retrieving Data.
# Processing record # 499: peniche
# Retrieving Data.
# Processing record # 500: tsihombe
# City data not found. Skipping city
# Processing record # 501: sola
# Retrieving Data.
# Processing record # 502: aripuana
# Retrieving Data.
# Processing record # 503: cocal
# Retrieving Data.
# Processing record # 504: songjianghe
# Retrieving Data.
# Processing record # 505: tawkar
# City data not found. Skipping city
# Processing record # 506: bur gabo
# City data not found. Skipping city
# Processing record # 507: canas
# Retrieving Data.
# Processing record # 508: north port
# Retrieving Data.
# Processing record # 509: shingu
# Retrieving Data.
# Processing record # 510: taian
# Retrieving Data.
# Processing record # 511: iralaya
# Retrieving Data.
# Processing record # 512: ulvik
# Retrieving Data.
# Processing record # 513: moctezuma
# Retrieving Data.
# Processing record # 514: larsnes
# Retrieving Data.
# Processing record # 515: caborca
# Retrieving Data.
# Processing record # 516: katobu
# Retrieving Data.
# Processing record # 517: bucksport
# Retrieving Data.
# Processing record # 518: mindelo
# Retrieving Data.
# Processing record # 519: zurrieq
# Retrieving Data.
# Processing record # 520: kieta
# Retrieving Data.
# Processing record # 521: haapiti
# Retrieving Data.
# Processing record # 522: barsanesti
# City data not found. Skipping city
# Processing record # 523: bath
# Retrieving Data.
# Processing record # 524: bogande
# Retrieving Data.
# Processing record # 525: batagay
# Retrieving Data.
# Processing record # 526: cuamba
# Retrieving Data.
# Processing record # 527: sokolovo
# Retrieving Data.
# Processing record # 528: galbshtadt
# Retrieving Data.
# Processing record # 529: cockburn harbour
# City data not found. Skipping city
# Processing record # 530: kunyang
# Retrieving Data.
# Processing record # 531: sabang
# Retrieving Data.
# Processing record # 532: kandrian
# Retrieving Data.
# Processing record # 533: lazaro cardenas
# Retrieving Data.
# Processing record # 534: celestun
# Retrieving Data.
# Processing record # 535: praya
# Retrieving Data.
# Processing record # 536: tofield
# Retrieving Data.
# Processing record # 537: inhambane
# Retrieving Data.
# Processing record # 538: egvekinot
# Retrieving Data.
# Processing record # 539: matadi
# Retrieving Data.
# Processing record # 540: ganzhou
# Retrieving Data.
# Processing record # 541: waipawa
# Retrieving Data.
# Processing record # 542: siljan
# Retrieving Data.
# Processing record # 543: ciudad guayana
# Retrieving Data.
# Processing record # 544: gazojak
# Retrieving Data.
# Processing record # 545: djenne
# Retrieving Data.
# Processing record # 546: abha
# Retrieving Data.
# Processing record # 547: stanger
# Retrieving Data.
# Processing record # 548: fredericton
# Retrieving Data.
# Processing record # 549: vieques
# Retrieving Data.
# Processing record # 550: chiriqui grande
# Retrieving Data.
# Processing record # 551: churapcha
# Retrieving Data.
# Processing record # 552: elko
# Retrieving Data.
# Processing record # 553: chumikan
# Retrieving Data.
# Processing record # 554: tapaua
# City data not found. Skipping city
# Processing record # 555: posse
# Retrieving Data.
# Processing record # 556: cabras
# Retrieving Data.
# Processing record # 557: gornopravdinsk
# Retrieving Data.
# Processing record # 558: la ceiba
# Retrieving Data.
# Processing record # 559: dilla
# Retrieving Data.
# Processing record # 560: halalo
# City data not found. Skipping city
# Processing record # 561: maceio
# Retrieving Data.
# Processing record # 562: agadez
# Retrieving Data.
# Processing record # 563: acandi
# Retrieving Data.
# Processing record # 564: nancha
# Retrieving Data.
# Processing record # 565: lokosovo
# Retrieving Data.
# Processing record # 566: panguna
# Retrieving Data.
# Processing record # 567: kolding
# Retrieving Data.
# Processing record # 568: catuday
# Retrieving Data.
# Processing record # 569: tabiauea
# City data not found. Skipping city
# Processing record # 570: cangucu
# Retrieving Data.
# Processing record # 571: chagda
# City data not found. Skipping city
# Processing record # 572: nioki
# Retrieving Data.
# Processing record # 573: madimba
# Retrieving Data.
# Processing record # 574: severo-kurilsk
# Retrieving Data.
# Processing record # 575: maridi
# Retrieving Data.
# Processing record # 576: kharp
# Retrieving Data.
# Processing record # 577: jutai
# Retrieving Data.
# Processing record # 578: dubti
# Retrieving Data.
# Processing record # 579: parksville
# Retrieving Data.
# Processing record # 580: coahuayana
# Retrieving Data.
# Processing record # 581: keti bandar
# Retrieving Data.
# Processing record # 582: rabak
# Retrieving Data.
# Processing record # 583: biltine
# Retrieving Data.
# Processing record # 584: najran
# Retrieving Data.
# Processing record # 585: ngunguru
# Retrieving Data.
# Processing record # 586: arecibo
# Retrieving Data.
# Processing record # 587: warqla
# City data not found. Skipping city
# Processing record # 588: abu dhabi
# Retrieving Data.
# Processing record # 589: pathein
# Retrieving Data.
# Processing record # 590: isiro
# Retrieving Data.
# Processing record # 591: port macquarie
# Retrieving Data.
# Processing record # 592: poum
# Retrieving Data.
# Processing record # 593: mizdah
# Retrieving Data.
# Processing record # 594: omsukchan
# Retrieving Data.
# Processing record # 595: chute-aux-outardes
# Retrieving Data.
# Processing record # 596: eyrarbakki
# Retrieving Data.
# Processing record # 597: presidencia roque saenz pena
# Retrieving Data.
# Processing record # 598: otane
# Retrieving Data.
# Processing record # 599: gouyave
# Retrieving Data.
# Processing record # 600: jardim
# Retrieving Data.
# Processing record # 601: mrirt
# City data not found. Skipping city
# Processing record # 602: dvinskoy
# Retrieving Data.
# Processing record # 603: hirara
# Retrieving Data.
# Processing record # 604: itumba
# Retrieving Data.
# Processing record # 605: quatre cocos
# Retrieving Data.
# Processing record # 606: witrivier
# City data not found. Skipping city
# Processing record # 607: hosakote
# Retrieving Data.
# Processing record # 608: mazeikiai
# Retrieving Data.
# Processing record # 609: tambacounda
# Retrieving Data.
# Processing record # 610: odweyne
# Retrieving Data.
# Processing record # 611: kurilsk
# Retrieving Data.
# Processing record # 612: nouadhibou
# Retrieving Data.
# Processing record # 613: khombole
# Retrieving Data.
# Processing record # 614: bolobo
# Retrieving Data.
#                    City  Cloudiness (%) Country        Date  Humidity  \
# 0            Oranjestad              20      AW  1583987322        74
# 1  Linxia Chengguanzhen              66      CN  1583987323        29
# 2          Koshurnikovo             100      RU  1583987324        82
# 3                Albany              90      US  1583987325        55
# 4               Ushuaia              90      AR  1583987045        93
#
#    Latitude  Longitude  Max Temp  Wind Speed
# 0     12.52     -70.03    299.15        8.70
# 1     35.60     103.21    274.53        3.14
# 2     54.17      93.30    265.32        1.04
# 3     42.60     -73.97    275.93        2.60
# 4    -54.80     -68.30    281.15        1.50

# %%
# Exporting output to csv file
city_temp_df.to_csv('cities_weather_data.csv')
